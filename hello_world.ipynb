# %% [markdown]
# # Hello World 验证
#
# 本 Notebook 用于验证 Python / Anaconda / Jupyter 环境是否正常。

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
import sys
print("Python 版本:", sys.version)
print("可执行路径:", sys.executable)
# Out:
# Python 版本: 3.14.6 | packaged by Anaconda, Inc. | (main, Jul  9 2026, 14:29:05) [MSC v.1942 64 bit (AMD64)]
# 可执行路径: D:\Anaconda3\python.exe

# %%
import platform
print("操作系统:", platform.system(), platform.release())
print("架构:", platform.machine())
# Out:
# 操作系统: Windows 11
# 架构: AMD64
